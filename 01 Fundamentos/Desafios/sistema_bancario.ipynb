# %% [markdown]
# Primeira versão do sistema com apenas 3 operações: depósito, saque e extrato

# %%
saldo = 0
transacoes = []

while True:
    print("\n=== Sistema Bancário ===")
    print("1. Depósito")
    print("2. Saque")
    print("3. Extrato")
    print("4. Sair")
    
    opcao = input("Selecione uma operação (1-4): ")
    
    if opcao == "1": 
        valor = float(input("Digite o valor do depósito: "))
        if valor > 0:
            saldo += valor
            transacoes.append(f"Depósito: +R${valor:.2f}")
            print(f"Depósito de R${valor:.2f} realizado com sucesso!")
        else:
            print("Valor inválido! O depósito deve ser maior que zero.")
    
    elif opcao == "2": 
        valor = float(input("Digite o valor do saque: "))
        if valor > 0:
            if valor <= saldo:
                saldo -= valor
                transacoes.append(f"Saque: -R${valor:.2f}")
                print(f"Saque de R${valor:.2f} realizado com sucesso!")
            else:
                print("Saldo insuficiente!")
        else:
            print("Valor inválido! O saque deve ser maior que zero.")
    
    elif opcao == "3": 
        print("\n=== Extrato ===")
        if not transacoes:
            print("Nenhuma transação realizada.")
        else:
            for transacao in transacoes:
                print(transacao)
        print(f"Saldo atual: R${saldo:.2f}")
    
    elif opcao == "4":
        print("Saindo do sistema. Obrigado!")
        break
    
    else:
        print("Opção inválida! Escolha entre 1 e 4.")
# Out:
# === Sistema Bancário ===
# 1. Depósito
# 2. Saque
# 3. Extrato
# 4. Sair
# Depósito de R$1000.00 realizado com sucesso!
#
# === Sistema Bancário ===
# 1. Depósito
# 2. Saque
# 3. Extrato
# 4. Sair
# Saque de R$300.00 realizado com sucesso!
#
# === Sistema Bancário ===
# 1. Depósito
# 2. Saque
# 3. Extrato
# 4. Sair
#
# === Extrato ===
# Depósito: +R$1000.00
# Saque: -R$300.00
# Saldo atual: R$700.00
#
# === Sistema Bancário ===
# 1. Depósito
# 2. Saque
# 3. Extrato
# 4. Sair
# Saldo insuficiente!
#
# === Sistema Bancário ===
# 1. Depósito
# 2. Saque
# 3. Extrato
# 4. Sair
# Saque de R$299.00 realizado com sucesso!
#
# === Sistema Bancário ===
# 1. Depósito
# 2. Saque
# 3. Extrato
# 4. Sair
#
# === Extrato ===
# Depósito: +R$1000.00
# Saque: -R$300.00
# Saque: -R$299.00
# Saldo atual: R$401.00
#
# === Sistema Bancário ===
# 1. Depósito
# 2. Saque
# 3. Extrato
# 4. Sair
# Saindo do sistema. Obrigado!
